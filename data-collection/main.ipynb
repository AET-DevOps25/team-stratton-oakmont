# %%
import requests
from lxml import html

# URL of the page to scrape
base_url = "https://campus.tum.de/tumonline"
study_programs_url = base_url + "/wbstpportfolio.wbStpList?pOrgNr=1&pSort=&pLanguageCode=DE&pStpStatus=N&pSjNr=1621"

# Fetch the page
study_programs = requests.get(study_programs_url)
study_programs.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<!-- PAGEID:7013870 KurzBez:7027640 -->\n<HTML lang="de" id="id-page-7027640" class="fwk-co app-str">\n<head>\n<meta http-equiv="Content-Type" name="" content="text/html; charset=UTF-8"><meta http-equiv="" name="viewport" content="width=device-width, initial-scale=1"><meta http-equiv="pragma" name="" content="no-cache"><meta http-equiv="" name="Author" content="Technische Universit\xc3\xa4t M\xc3\xbcnchen">\n\n<title>Studienangebot - TUMonline - Technische Universit\xc3\xa4t M\xc3\xbcnchen</title>\n\n        <script type="text/javascript">\n        window.caGlobalContext = {};\n        if (window.CA_THEME_CACHE_TOKEN) {\n          window.caGlobalContext.antiCacheToken = window.CA_THEME_CACHE_TOKEN;\n        } else {\n          window.caGlobalContext.antiCacheToken = \'1510687599792\';\n        }\n\n        var css =\n            "<link rel=\'stylesheet\' href=\'pages/co-default/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "\'>" +\n            "<link id=\'id-custom-css-vars\' rel=\'stylesheet\' href=\'pages/co-user/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "\'>";\n        console.log(\'Adding css coplslq: \', css);\n        document.write(css);\n        </script>\n        \n<script src="https://campus.tum.de/tumonline/ee/theme/ca2/scripts/conx-custom-scripts.js"></script>\n<link rel="shortcut icon" href="/tumprod/img/co_favicon_tumprod.gif?20101006133616">\n<STYLE type="text/css">\n  A { text-decoration:underline;} \n  BODY { font-size:14px;background-image:url(/tumprod/img/background_production.svg?20210203074442);} \n</STYLE>\n<link rel="stylesheet" type="text/css" href="/tumprod/css/system_standard.css?20241217071038">\n<style media="screen" type="text/css">\n\n</style> <style media="print, screen" type="text/css">  ul.mktree li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li ul li div.contentDiv { font-size: 1.2em; } ul.mktree li ul li ul li ul li div.contentDiv { font-size: 1em; }  </style> <style media="screen, projection" type="text/css">  ul.mktree li.liBullet img { padding-left: 1.3em; }  </style> <link rel="stylesheet" type="text/css" href="/tumprod/css/custom_standard.css?20250509185524">\n\n<script type="text/javascript">\n <!-- \n var GLOBALhomeUrl = "campus.tum.de";\n var GLOBALhomeIndicator = "<img src=\'/tumprod/img/co_logo_m_tumprod.gif?20160914063132\' BORDER=0 />";\nvar GLOBALLOVSucheArr = new Array();\n//-->\n</script>\n</head>\n<body onLoad="if ( parent && window && parent != window ) { var vTitle =\' \'; if( parent && parent.detail && parent.detail.document.title ) { vTitle = vTitle.concat(parent.detail.document.title.replace(/[\\n\\r\\x22\\\']|^\\s*/g, \'\')); parent.document.title = vTitle; } else { if( parent && parent.frames[0] && parent.frames[0].document.title ) {vTitle = vTitle.concat(parent.frames[0].document.title.replace(/[\\n\\r\\x22\\\']|^\\s*/g, \'\')); parent.document.title = vTitle; } } }"  >\n<div id="idEePageWrapper">\n\n<div class="pageDisabled" id="idPageDisabled">\n</div>\n<div class="pageLoading" id="idPageLoader">\nLoading\n</div>\n<script charset="WINDOWS-1252" type="text/javascript">\n\n  if(window.addEventListener) window.addEventListener("load", function(){ $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none";}, false);\n  else {  document.attachEvent("onreadystatechange", function(){ if(document.readyState == "complete") { $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none"; }  }, false);  }\n\n</script>\n<link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/styles-integration.css" media="screen"></link>\n<link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/co-web-cmp.css">\n<div id="id-loader"><span>Loading ...</span></div>\n<co ...

# %%
# Parse the HTML content
study_programs_content_html = html.fromstring(study_programs.content)
# Show the HTML structure
print(html.tostring(study_programs_content_html, pretty_print=True).decode())
# Out:
# <html lang="de" id="id-page-7027640" class="fwk-co app-str">
# <head>
#
# <meta http-equiv="" name="viewport" content="width=device-width, initial-scale=1">
# <meta http-equiv="pragma" name="" content="no-cache">
# <meta http-equiv="" name="Author" content="Technische Universit&#228;t M&#252;nchen">
#
# <title>Studienangebot - TUMonline - Technische Universit&#228;t M&#252;nchen</title>
#
#         <script type="text/javascript">
#         window.caGlobalContext = {};
#         if (window.CA_THEME_CACHE_TOKEN) {
#           window.caGlobalContext.antiCacheToken = window.CA_THEME_CACHE_TOKEN;
#         } else {
#           window.caGlobalContext.antiCacheToken = '1510687599792';
#         }
#
#         var css =
#             "<link rel='stylesheet' href='pages/co-default/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "'>" +
#             "<link id='id-custom-css-vars' rel='stylesheet' href='pages/co-user/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "'>";
#         console.log('Adding css coplslq: ', css);
#         document.write(css);
#         </script>
#
# <script src="https://campus.tum.de/tumonline/ee/theme/ca2/scripts/conx-custom-scripts.js"></script>
# <link rel="shortcut icon" href="/tumprod/img/co_favicon_tumprod.gif?20101006133616">
# <style type="text/css">
#   A { text-decoration:underline;}
#   BODY { font-size:14px;background-image:url(/tumprod/img/background_production.svg?20210203074442);}
# </style>
# <link rel="stylesheet" type="text/css" href="/tumprod/css/system_standard.css?20241217071038">
# <style media="screen" type="text/css">
#
# </style> <style media="print, screen" type="text/css">  ul.mktree li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li ul li div.contentDiv { font-size: 1.2em; } ul.mktree li ul li ul li ul li div.contentDiv { font-size: 1em; }  </style> <style media="screen, projection" type="text/css">  ul.mktree li.liBullet img { padding-left: 1.3em; }  </style> <link rel="stylesheet" type="text/css" href="/tumprod/css/custom_standard.css?20250509185524">
#
# <script type="text/javascript">
#  <!--
#  var GLOBALhomeUrl = "campus.tum.de";
#  var GLOBALhomeIndicator = "<img src='/tumprod/img/co_logo_m_tumprod.gif?20160914063132' BORDER=0 />";
# var GLOBALLOVSucheArr = new Array();
# //-->
# </script>
# </head>
# <body onload="if ( parent &amp;&amp; window &amp;&amp; parent != window ) { var vTitle =' '; if( parent &amp;&amp; parent.detail &amp;&amp; parent.detail.document.title ) { vTitle = vTitle.concat(parent.detail.document.title.replace(/[\n\r\x22\']|^\s*/g, '')); parent.document.title = vTitle; } else { if( parent &amp;&amp; parent.frames[0] &amp;&amp; parent.frames[0].document.title ) {vTitle = vTitle.concat(parent.frames[0].document.title.replace(/[\n\r\x22\']|^\s*/g, '')); parent.document.title = vTitle; } } }">
# <div id="idEePageWrapper">
#
# <div class="pageDisabled" id="idPageDisabled">
# </div>
# <div class="pageLoading" id="idPageLoader">
# Loading
# </div>
# <script charset="WINDOWS-1252" type="text/javascript">
#
#   if(window.addEventListener) window.addEventListener("load", function(){ $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none";}, false);
#   else {  document.attachEvent("onreadystatechange", function(){ if(document.readyState == "complete") { $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none"; }  }, false);  }
#
# </script>
# <link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/styles-integration.css" media="screen">
# <link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/co-web-cmp.css">
# <div id="id-loader"><span>Loading ...</span></div>
# <co-web-desktop-header></co-web-desktop-header>
# <div id="pageContent">
# <div class="coTooltip" id="GLOBALcoTooltip"></div>
# <table align="center" width="100%" id="idTopPageHeader" class="bodyTable" cellspacing="0" cellpadding="0">
# <tr valign="middle" class="middle coHeaderTopRow">
# <td nowrap class="pageOwner"><span class="s"><a href="wborg.display?pOrgNr=1">Technische Universit&#228;t M&#252;nchen</a></span></td>
# <td class="wr100" width="100%">&#160;</td>
# <td>&#160;</td>
# <td></td>
# <td>
# <script src="/tumprod/js/wosinddieframes.jsa?20110330194606" type="text/javascript" charset="WINDOWS-1252"></script>
# </td>
# </tr>
# </table>
# <table align="center" width="100%" id="idPageHeader" class="pageObjectNoTopBorder" cellspacing="0" cellpadding="0">
# <tr align="left" valign="top">
# <td valign="middle" style="padding:10px;width:50%;">
# <table width="100%">
# <tr valign="top">
# <td width="100%"><h1 class="headerHeading noMargin">Studienangebot</h1></td>
# </tr>
# <tr valign="top" style="vertical-align:middle">
# <td width="100%"><h2 class="m normalWeight headerObject noMargin" id="idCaSubTitle">2025/26</h2></td>
# </tr>
# </table>
# </td>
# <td align="right">
# <table id="idPageNavi" class="nav puNav caCoFwk" summary="Men&#252;">
# <tr class="coNavSection ca-key-id ca-id-nav-anzeige">
# <th nowrap>Anzeige</th>
# <td>
#
# </td>
# </tr>
# <tr class="coNavGroup ca-key-id ca-id-nav-studienjahr">
# <th nowrap>Studienjahr</th>
# <td>
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1621" class="disabled selected  ca-dynamic-id ca-id-2025/26" id="Anchor33063382296" onclick="try{ return(false);}catch(e){return($E(e));}">2025/26</a>
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1619" class="ca-dynamic-id ca-id-2024/25" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2024/25</a>
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1617" class="ca-dynamic-id ca-id-2023/24" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2023/24</a>
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1615" class="ca-dynamic-id ca-id-2022/23" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2022/23</a>
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1613" class="ca-dynamic-id ca-id-2021/22" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2021/22</a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <div class="invisible" id="idMsgLayerClosed">
# <a href="#" class=" nounderline" id="idToolUnClose" onclick="try{CO.msg.unClose(); return(false);}catch(e){return($E(e));}"><img alt="Meldungen anzeigen" height="24" src="/tumprod/img/msg_maximize.png?20120725215601" width="24"></a><a href="#" class=" nounderline" onclick="try{CO.msg.clear(true); return(false);}catch(e){return($E(e));}"><img alt="Meldungsfenster schlie&#223;en" height="24" src="/tumprod/img/msg_close.png?20120725215554" width="24"></a>
# </div>
# <div id="idMsgLayer">
# <div class="toolbar" id="idToolbar">
# <span class="toolbarSummary invisible" id="idToolbarSummary"><a href="#" class="invisible  nounderline" id="idToolFatalSummary" onclick='try{CO.msg.focus($$(".msgFatal")[0]); return(false);}catch(e){return($E(e));}'><img alt="Fatale Fehler" height="21" src="/tumprod/img/msg_fatal_small.gif?20080430220108" width="21"></a><a href="#" class="invisible  nounderline" id="idToolErrorSummary" onclick='try{CO.msg.focus($$(".msgError")[0]); return(false);}catch(e){return($E(e));}'><img alt="Fehler" height="21" src="/tumprod/img/msg_error_small.gif?20080430220106" width="21"></a><a href="#" class="invisible  nounderline" id="idToolWarningSummary" onclick='try{CO.msg.focus($$(".msgWarning")[0]); return(false);}catch(e){return($E(e));}'><img alt="Warnungen" height="21" src="/tumprod/img/msg_warning_small.gif?20080430220113" width="21"></a><a href="#" class="invisible  nounderline" id="idToolInfoSummary" onclick='try{CO.msg.focus($$(".msgInfo")[0]); return(false);}catch(e){return($E(e));}'><img alt="Informationen" height="21" src="/tumprod/img/msg_info_small.gif?20080430220109" width="23"></a></span><a href="#" class=" nounderline" onclick="try{CO.msg.close(); return(false);}catch(e){return($E(e));}"><img alt="Wichtigste Meldungen anzeigen" height="24" src="/tumprod/img/msg_minimize.png?20120725215605" width="24"></a><a href="#" class="invisible  nounderline" id="idToolMinimize" onclick="try{CO.msg.showMinimized(); return(false);}catch(e){return($E(e));}"><img alt="Wichtigste Meldungen anzeigen" height="24" src="/tumprod/img/msg_diminish.png?20120725215557" width="24"></a><a href="#" class="invisible  nounderline" id="idToolMaximize" onclick="try{CO.msg.showMaximized(); return(false);}catch(e){return($E(e));}"><img alt="Alle Meldungen anzeigen" height="24" src="/tumprod/img/msg_maximize.png?20120725215601" width="24"></a><a href="#" class=" nounderline" onclick="try{CO.msg.clear(true); return(false);}catch(e){return($E(e));}"><img alt="Meldungsfenster schlie&#223;en" height="24" src="/tumprod/img/msg_close.png?20120725215554" width="24"></a>
# </div>
# <div class="msgs">
# <ul class="msgFatal">
# <li>
# </li>
# </ul>
# <ul class="msgError">
# <li>
# </li>
# </ul>
# <ul class="msgWarning">
# <li>
# </li>
# </ul>
# <ul class="msgInfo">
# <li>
# </li>
# </ul>
# </div>
# </div>
# <script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# document.getElementById("idMsgLayer").style.display = "none";
# //]]>
# </script><div id="idErrorBox">
# </div>
# <div id="cStpList">
# <form action="" enctype="" method="POST" name="Mask33063382297" onsubmit="try{return CO.Mask.submitHandler(this);}catch(e){return($E(e));}" class="coBBNoCSS " id="Mask33063382297">
# <table cellspacing="0" class="cotable" id="idStpList">
# <thead>
# <tr>
# <th colspan="1" class=" L" id="idCOTH33063382323">
# <div>
# <span>Abschlussziel</span><span><span class="headerToolSpacer ">&#160;</span></span><span><a href="#" class="headerTool  nounderline" onclick='try{CO.Table.goTo($("idStpList"), null, null, true, "-2");   return(false);}catch(e){return($E(e));}' title="aufsteigend sortiert, klick um absteigend zu sortieren"><img alt="" height="14" src="/tumprod/img/tableheader_sort_down_active.gif?20130606222106" width="14"></a></span><span><a href="#" class="headerTool  nounderline" id="idFilterA33063382325" onclick="try{return(false);}catch(e){return($E(e));}" title="ungefiltert, klick um Filter anzuzeigen"><img alt="" height="14" src="/tumprod/img/tableheader_filter_inactive.gif?20101207172149" width="14"></a></span>
# </div>
# </th>
# <th colspan="1" class=" L" id="idCOTH33063382326">
# <div>
# <span>Kennzahl</span><span><span class="headerToolSpacer ">&#160;</span></span><span><a href="#" class="headerTool  nounderline" id="idFilterA33063382328" onclick="try{return(false);}catch(e){return($E(e));}" title="ungefiltert, klick um Filter anzuzeigen"><img alt="" height="14" src="/tumprod/img/tableheader_filter_inactive.gif?20101207172149" width="14"></a></span>
# </div>
# </th>
# <th colspan="1" class=" L" id="idCOTH33063382329">
# <div>
# <span>Studienplan</span><span><span class="headerToolSpacer ">&#160;</span></span><span><a href="#" class="headerTool  nounderline" id="idFilterA33063382331" onclick="try{return(false);}catch(e){return($E(e));}" title="ungefiltert, klick um Filter anzuzeigen"><img alt="" height="14" src="/tumprod/img/tableheader_filter_inactive.gif?20101207172149" width="14"></a></span>
# </div>
# </th>
# <th colspan="1" class=" C" id="idCOTH33063382332">
# <div>
# <span>Studienrichtung</span><span><span class="headerToolSpacer ">&#160;</span></span><span><a href="#" class="headerTool  nounderline" onclick='try{CO.Table.goTo($("idStpList"), null, null, true, "4");   return(false);}catch(e){return($E(e));}' title="unsortiert, klick um aufsteigend zu sortieren"><img alt="" height="14" src="/tumprod/img/tableheader_sort_down_inactive.gif?20130606222106" width="14"></a></span><span><a href="#" class="headerTool  nounderline" id="idFilterA33063382334" onclick="try{return(false);}catch(e){return($E(e));}" title="ungefiltert, klick um Filter anzuzeigen"><img alt="" height="14" src="/tumprod/img/tableheader_filter_inactive.gif?20101207172149" width="14"></a></span>
# </div>
# </th>
# <th colspan="1" class=" C">
# ECTS-Credits</th>
# <th colspan="1" class=" C">
# Semester</th>
# <th colspan="1" class=" C">
# akad. Grad</th>
# <th colspan="1" class=" C">
# Evaluierung</th>
# </tr>
# </thead>
# <tfoot>
# <tr>
# <th colspan="8" class="ftr">
# &#160;
# <span id="idTimer33063382298"></span>
# </th>
# </tr>
# </tfoot>
# <tbody>
# <tr class="coRow coTableGR1   ">
# <td colspan="8">
# <a href="#" class=" nounderline" onclick='try{CO.Tools.coToggle($("4857"), {mImg: this, mExpandIcon: "/tumprod/img/expand.gif?20190429135420",  mCollapsIcon: "/tumprod/img/collaps.gif?20190429135418", onExpand: function(){$$(".1").each(function(e){e.removeClassName("invisible");});}, onCollapse:function(){$$(".1").each(function(e){ e.addClassName("invisible");});}}); return(false);}catch(e){return($E(e));}'><img alt="" height="16" src="/tumprod/img/expand.gif?20190429135420" width="16"></a> 04 TopMath Promotion<a name="coTblIdx_idStpList_1"></a>
# </td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  1 " id="4857">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_1" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_1" onclick="try{ return(false);}catch(e){return($E(e));}"></a>04 TopMath Promotion</td>
# <td class=" L">084</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Mathe. mit zus&#228;tzl. Promo.stg. Mathe. - Promotion (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Mathe. mit zus&#228;tzl. Promo.stg. Mathe. - Promotion 20191">20191</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Mathematik</td>
# <td class=" C"></td>
# <td class=" C">8</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow coTableGR1   ">
# <td colspan="8">
# <a href="#" class=" nounderline" onclick='try{CO.Tools.coToggle($("4094"), {mImg: this, mExpandIcon: "/tumprod/img/expand.gif?20190429135420",  mCollapsIcon: "/tumprod/img/collaps.gif?20190429135418", onExpand: function(){$$(".2").each(function(e){e.removeClassName("invisible");});}, onCollapse:function(){$$(".2").each(function(e){ e.addClassName("invisible");});}}); return(false);}catch(e){return($E(e));}'><img alt="" height="16" src="/tumprod/img/expand.gif?20190429135420" width="16"></a> 05 Teilpromotion<a name="coTblIdx_idStpList_2"></a>
# </td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4094">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_2" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_2" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">701</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4094&amp;pStartSemester=">Agrarwissenschaften (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Agrarwissenschaften 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Agrarwissenschaft/Landwirtschaft</td>
# <td class=" C">6</td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2550">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_3" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_3" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">350</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2550&amp;pStartSemester=">Architektur (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Architektur 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Architektur</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="2722">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_4" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_4" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">310</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Bauingenieurwesen (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Bauingenieurwesen 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Bauingenieurwesen/Ingenieurbau</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="4127">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_5" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_5" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">105</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4127&amp;pStartSemester=">Biochemie (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Biochemie 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Biochemie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4234">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_6" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_6" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">042</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4234&amp;pStartSemester=">Bioinformatik (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Bioinformatik 0, studierbar bis 30.09.2050">0; sb bis 30.09.2050</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Informatik</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2897">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_7" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_7" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">110</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2897&amp;pStartSemester=">Biologie (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Biologie 0, studierbar bis 30.09.2030">0; sb bis 30.09.2030</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Biologie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4128">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_8" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_8" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">800</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4128&amp;pStartSemester=">Brauwesen und Getr&#228;nketechnologie (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Brauwesen und Getr&#228;nketechnologie 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Brauwesen/Getr&#228;nketechnologie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2551">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_9" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_9" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">100</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2551&amp;pStartSemester=">Chemie (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Chemie 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Chemie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4160">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_10" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_10" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">415</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4160&amp;pStartSemester=">Chemie-Ingenieurwesen (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Chemie-Ingenieurwesen 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Chemie-Ingenieurwesen/Chemietechnik</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2993">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_11" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_11" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">761</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2993&amp;pStartSemester=">Ern&#228;hrungswissenschaft (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Ern&#228;hrungswissenschaft 0, studierbar bis 30.09.2030">0; sb bis 30.09.2030</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Haushalts- und Ern&#228;hrungswissenschaft</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4622">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_12" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_12" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">610</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Fakult&#228;t TUM School of Education (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Fakult&#228;t TUM School of Education 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Erziehungswissenschaft (P&#228;dagogik)</td>
# <td class=" C"></td>
# <td class=" C">8</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="3371">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_13" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_13" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">750</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=3371&amp;pStartSemester=">Forstwissenschaft (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Forstwissenschaft 0, studierbar bis 30.09.2039">0; sb bis 30.09.2039</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Forstwissenschaft, -wirtschaft</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="3815">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_14" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_14" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">332</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Geod&#228;sie u.Geoinformation (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Geod&#228;sie und Geoinformation 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Vermessungswesen (Geod&#228;sie)</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="4483">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_15" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_15" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">130</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Geologie (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Geologie 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Geologie/Pal&#228;ontologie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="2803">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_16" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_16" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">030</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2803&amp;pStartSemester=">Informatik (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Informatik 0, studierbar bis 30.09.2039">0; sb bis 30.09.2039</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Informatik</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="4500">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_17" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_17" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">411</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Ingenieurwissenschaften (Engin. Science) (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Ingenieurwissenschaften (Engin. Science) 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Interdisziplin&#228;re Studien (Schwerpunkt Ingenieurwissenschaften)</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="3819">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_18" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_18" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">722</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=3819&amp;pStartSemester=">Landnutzung/Agrar-/Gartenbauwissenschaft (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Landnutzung-Agrarwissenschaft und Gartenbauwissenschaft 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Agrarwissenschaft/Landwirtschaft</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="4090">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_19" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_19" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">746</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4090&amp;pStartSemester=">Landschaftsarchitektur und Landschaftsplanung (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Landschaftsarchitektur und Landschaftsplanung 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Landespflege/Landschaftsgestaltung</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="4498">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_20" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_20" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">419</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Luft- und Raumfahrt (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Luft- und Raumfahrt 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Luft- und Raumfahrttechnik</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2636">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_21" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_21" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">401</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2636&amp;pStartSemester=">Maschinenwesen (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Maschinenwesen 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Maschinenbau/-wesen</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="3076">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_22" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_22" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">900</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=3076&amp;pStartSemester=">Medizin (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Medizin 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Medizin (Allgemein-Medizin)</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2799">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_23" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_23" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">051</td>
# <td class=" L">
# <div>
# <span><a href="javascript:alert('Details%20zum%20Curriculum%20sind%20im%20Studiensekretariat%20der%20betreuenden%20School%20zu%20erfragen.');">Physik (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Physik 0, studierbar bis 30.09.2036">0; sb bis 30.09.2036</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Physik</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="3089">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_24" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_24" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">291</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=3089&amp;pStartSemester=">Sportwissenschaft (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Sportwissenschaft 0, studierbar bis 30.09.2050">0; sb bis 30.09.2050</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Sportwissenschaft</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="4370">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_25" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_25" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">754</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4370&amp;pStartSemester=">Sustainable Resource Management (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Sustainable Resource Management 0">0</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Naturschutz</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z1 hi coTableR invisible  2 " id="2802">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_26" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_26" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">256</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2802&amp;pStartSemester=">Technologie- u. Managementorientierte BWL (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Technologie- u. Managementorientierte BWL 0, studierbar bis 30.09.2039">0; sb bis 30.09.2039</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Betriebswirtschaftslehre</td>
# <td class=" C"></td>
# <td class=" C">8</td>
# <td class=" C"></td>
# <td class=" C"><a href="javascript:alert('Melden%20Sie%20sich%20bitte%20an,%20um%20Evaluierungsergebnisse%20einzusehen!');"><img src="/tumprod/img/lv_grey.gif" alt="Zur Evaluierung des abgeschlossenen Studiums (Melden Sie sich bitte an, um Evaluierungsergebnisse einzusehen!)" border="0"></a></td>
# </tr>
# <tr class="coRow z0 hi coTableR invisible  2 " id="2984">
# <td class=" L">
# <a href="#" name="coTblIdx_idStpList_27" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("idStpList"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_idStpList_27" onclick="try{ return(false);}catch(e){return($E(e));}"></a>05 Teilpromotion</td>
# <td class=" L">830</td>
# <td class=" L">
# <div>
# <span><a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=2984&amp;pStartSemester=">Technologie und Biotechnologie der Lebensmittel (<span class="TextToolTip " title="unbekannte gesetzliche Grundlage">kA</span>/<span class="TextToolTip " title="Doktoratsstudium Technologie und Biotechnologie der Lebensmittel 0, studierbar bis 30.09.2030">0; sb bis 30.09.2030</span>)</a></span><span>&#160;</span><span><a href="#"></a></span><span>&#160;</span><span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">Lebensmitteltechnologie</td>
# <td class=" C"></td>
# <td class=" C">6</td>
# <td class=" C"></td>
# ...
# <td></td>
# </tr>
# </table>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="invisible">
# <div class="overlayTTContainer " id="Overlay33063382317">
# <form action="" enctype="" method="POST" name="Mask33063382318" onsubmit="try{return CO.Mask.submitHandler(this);}catch(e){return($E(e));}" id="Mask33063382318">
# <div class="MaskBackground">
# <div class=" MaskContent">
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT"></td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="toolButton commandButton " onclick="try{CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}"><span class="bold ">X</span></a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <div class=" MaskData">
# <table>
# <tr>
# <td colspan="1" class=" MaskRenderer top">
# <fieldset class=" MaskS MaskSCT " id="idFilterCT33063382303">
# <legend class="Mask " role="heading">
# <span class="Mask">Filtern</span>
# </legend>
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <table class=" MaskSpacing">
# <tr>
# <td class=" MaskRenderer  MaskLabel"><label for="IF33063382305" class="Mask ">Kennzahl</label></td>
# <td class=" MaskRenderer">
# <table class=" MaskElement">
# <tr>
# <td class=" MaskRenderer"><input name="f_10_10" size="9" type="text" id="IF33063382305" onkeypress="try{return nE(event);}catch(e){return($E(e));}"></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " onclick='try{CO.Table.deleteFilter($("idStpList"), $("idFilterCT33063382303"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filter aufheben</a>
# </li>
# </ul>
# </td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " id="idFilterCT33063382303Button" onclick='try{CO.Table.filter($("idStpList"), $("idFilterCT33063382303"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filtern</a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# </table>
# </fieldset>
# </td>
# </tr>
# </table>
# </div>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# </table>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="invisible">
# <div class="overlayTTContainer " id="Overlay33063382319">
# <form action="" enctype="" method="POST" name="Mask33063382320" onsubmit="try{return CO.Mask.submitHandler(this);}catch(e){return($E(e));}" id="Mask33063382320">
# <div class="MaskBackground">
# <div class=" MaskContent">
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT"></td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="toolButton commandButton " onclick="try{CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}"><span class="bold ">X</span></a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <div class=" MaskData">
# <table>
# <tr>
# <td colspan="1" class=" MaskRenderer top">
# <fieldset class=" MaskS MaskSCT " id="idFilterCT33063382306">
# <legend class="Mask " role="heading">
# <span class="Mask">Filtern</span>
# </legend>
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <table class=" MaskSpacing">
# <tr>
# <td class=" MaskRenderer  MaskLabel  top"><label for="TA33063382308" class="Mask ">Studienplan</label></td>
# <td class=" MaskRenderer"><textarea cols="50" name="f_8_10" rows="1" id="TA33063382308" onclick="try{ return(false);}catch(e){return($E(e));}">
# </textarea></td>
# </tr>
# </table>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " onclick='try{CO.Table.deleteFilter($("idStpList"), $("idFilterCT33063382306"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filter aufheben</a>
# </li>
# </ul>
# </td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " id="idFilterCT33063382306Button" onclick='try{CO.Table.filter($("idStpList"), $("idFilterCT33063382306"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filtern</a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# </table>
# </fieldset>
# </td>
# </tr>
# </table>
# </div>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# </table>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="invisible">
# <div class="overlayTTContainer " id="Overlay33063382321">
# <form action="" enctype="" method="POST" name="Mask33063382322" onsubmit="try{return CO.Mask.submitHandler(this);}catch(e){return($E(e));}" id="Mask33063382322">
# <div class="MaskBackground">
# <div class=" MaskContent">
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=4&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1621" class="toolButton commandButton " onclick='try{CO.Table.goTo($("idStpList"), null, null, true, "4"); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>&#9650;</a>
# </li>
# <li class=" coBB  bbModusdefault">
# <a href="wbstpportfolio.wbStpList?pOrgNr=1&amp;pSort=-4&amp;pLanguageCode=DE&amp;pStpStatus=N&amp;pSjNr=1621" class="toolButton commandButton " onclick='try{CO.Table.goTo($("idStpList"), null, null, true, "-4"); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>&#9660;</a>
# </li>
# </ul>
# </td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="toolButton commandButton " onclick="try{CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}"><span class="bold ">X</span></a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <div class=" MaskData">
# <table>
# <tr>
# <td colspan="1" class=" MaskRenderer top">
# <fieldset class=" MaskS MaskSCT " id="idFilterCT33063382309">
# <legend class="Mask " role="heading">
# <span class="Mask">Filtern</span>
# </legend>
# <table class="coBB">
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBTOP invisible"></td>
# <td colspan="2" rowspan="2" class="coBBContent">
# <table class=" MaskSpacing">
# <tr>
# <td class=" MaskRenderer  MaskLabel"><label class="Mask ">Studienrichtung</label></td>
# <td colspan="1" class=" MaskRenderer top">
# <table class=" MaskSpacing">
# <tr>
# </tr>
# <tr>
# <td class=" MaskRenderer  MaskLabel"><label for="IF33063382311" class="Mask "><span class="coFilterOperator TextToolTip " title="&#228;hnlich (Gro&#223;-/Kleinschreibungs-unabh&#228;ngig)">&#8776;</span></label></td>
# <td class=" MaskRenderer">
# <table class=" MaskElement">
# <tr>
# <td class=" MaskRenderer"><input name="f_7_10" size="42" type="text" id="IF33063382311" onkeypress="try{return nE(event);}catch(e){return($E(e));}"></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " onclick='try{CO.Table.deleteFilter($("idStpList"), $("idFilterCT33063382309"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filter aufheben</a>
# </li>
# </ul>
# </td>
# <td class=" coBBBRIGHT coBB">
# <ul class="coBB">
# <li class=" coBB  bbModusdefault">
# <a href="#" class="commandButton " id="idFilterCT33063382309Button" onclick='try{CO.Table.filter($("idStpList"), $("idFilterCT33063382309"), ""); CO.Table.Tools.hide(); return(false);}catch(e){return($E(e));}'>Filtern</a>
# </li>
# </ul>
# </td>
# <td></td>
# </tr>
# </table>
# </fieldset>
# </td>
# </tr>
# </table>
# </div>
# </td>
# <td class=" coBBRIGHT coBBBTOP invisible"></td>
# </tr>
# <tr>
# <td class=" coBBLEFT coBBBBOTTOM invisible coBB"></td>
# <td class=" coBBRIGHT coBBBBOTTOM invisible coBB"></td>
# </tr>
# <tr class="coBB">
# <td></td>
# <td class=" coBBBLEFT invisible"></td>
# <td class=" coBBBRIGHT invisible coBB"></td>
# <td></td>
# </tr>
# </table>
# </div>
# </div>
# </form>
# </div>
# </div>
# <!--
#  ToolTip Overlays end-->
# <div class="invisible" id="ToolTipOverlayCBCT">
# </div>
# <script charset="WINDOWS-1252" src="/tumprod/js/prototype.js?20230718075524" type="text/javascript"></script><script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# if(typeof(CO) === "undefined")
#   var CO = Class.create();
# CO.IMGPATH = "https://campus.tum.de/tumprod/img/";
# //]]>
# </script><script charset="WINDOWS-1252" src="/tumprod/js/scriptaculous.jsa?20080730194911" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/effects.jsa?20080730194907" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/dragdrop.jsa?20090318173923" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cojs.jsa?20250513075455" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cotable.jsa?20170405175145" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/coeffect.jsa?20150126164151" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/comsg.jsa?20150506180429" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/utf8count.jsa?20250324091721" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/system_standard_js.js?20110525190919" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/co_loc_custom_standard_js.js?20250314181441" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cocallback.jsa?20231010073535" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/coautosuggestion.js?20131216170447" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/comaskjs.jsa?20250218080956" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/wbjsincludes_de.js" type="text/javascript"></script>
#
# <script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# $NS("js_icons");
# self.js_icons.idNav33063382295_minus_img = new CO.Image("/tumprod/img/menu_tee_minus_m_tumprod.png?20160914063609", "", {"class" : ""});
# self.js_icons.idNav33063382295_plus_img = new CO.Image("/tumprod/img/menu_tee_plus_m_tumprod.png?20160914063623", "", {"class" : ""});
# self.js_icons.idNav33063382295_chkbox_unselected = new CO.Image("/tumprod/img/checkbox_unchecked.png?20080825172356", "", {"class" : ""});
# self.js_icons.idNav33063382295_chkbox_selected = new CO.Image("/tumprod/img/checkbox_checked.png?20080825172351", "", {"class" : ""});
# self.js_icons.idNav33063382295_chkbox_halfselected = new CO.Image("/tumprod/img/checkbox_grey.png?20080825172353", "", {"class" : ""});
#  if ( window.jsTree == undefined ) { window.jsTree = new Object(); };
#  if($("idFilterA33063382325")) $("idFilterA33063382325").observe("click", function(event){ CO.Filter.showFilter($("idCOTH33063382323"), $("Overlay33063382315"), $("idCOTH33063382323")); Event.stop(event);  })
#  if($("idFilterA33063382328")) $("idFilterA33063382328").observe("click", function(event){ CO.Filter.showFilter($("idCOTH33063382326"), $("Overlay33063382317"), $("idCOTH33063382326")); Event.stop(event);  })
#  if($("idFilterA33063382331")) $("idFilterA33063382331").observe("click", function(event){ CO.Filter.showFilter($("idCOTH33063382329"), $("Overlay33063382319"), $("idCOTH33063382329")); Event.stop(event);  })
#  if($("idFilterA33063382334")) $("idFilterA33063382334").observe("click", function(event){ CO.Filter.showFilter($("idCOTH33063382332"), $("Overlay33063382321"), $("idCOTH33063382332")); Event.stop(event);  })
# if($CO("idStpList")) $CO("idStpList").co.mTableUrlJSId = "cb186619659"; // new
# if($CO("idStpList")) $CO("idStpList").co.mPageParamName = "pPageNr"; // new
# if($CO("idStpList"))  $CO("idStpList").co.mSortParamName = "pSort"; // new
# if($CO("idStpList"))  $CO("idStpList").co.mFilterParamName = "pFilter"; // new
# if($CO("idStpList"))  $CO("idStpList").co.mPageNr = "1"; // new
# if($CO("idStpList")) $CO("idStpList").co.mCallbackMode = false; // new
# if($("idStpList")) $CO("idStpList").co.multiple = true;
# CO.Table.init("idStpList");
# self.coOverLay = function(pId, pComponent, pFixed)
# {
# vTip = new Tip(pId, pComponent ,{ fixed: pFixed });
# };
# window.as_IF33063382305 = new CO.AutoSuggestion("cb186621598",{"delay" : 500,"max_height" : 200,"min_length" : 1,"wa_info_text" : "%result_nr% Ergebnisse gefunden. Sie befinden sich in einer Autovervollst&#228;ndigungTextbox, mit den Pfeiltasten Nachoben und Nachunten k&#246;nnen Sie navigieren oder normal weiterschreiben.","caching" : true,"event_trigger" : "keyup"}).registerTextBox($("IF33063382305"));
# window.as_TA33063382308 = new CO.AutoSuggestion("cb186621599",{"delay" : 500,"max_height" : 200,"min_length" : 2,"wa_info_text" : "%result_nr% Ergebnisse gefunden. Sie befinden sich in einer Autovervollst&#228;ndigungTextbox, mit den Pfeiltasten Nachoben und Nachunten k&#246;nnen Sie navigieren oder normal weiterschreiben.","caching" : true,"event_trigger" : "keyup"}).registerTextBox($("TA33063382308"));
# CO.observe($("Anchor33063382296"), "click", {}, function(event){CO.Page.disable(); CO.Page.loading();;});
# CO.observe($("idFilterCT33063382300"), "keydown", {key: Event.KEY_RETURN}, function(event){if($("idFilterCT33063382300Button")){ $("idFilterCT33063382300Button").onclick(); }});
# CO.observe($("idFilterCT33063382303"), "keydown", {key: Event.KEY_RETURN}, function(event){if($("idFilterCT33063382303Button")){ $("idFilterCT33063382303Button").onclick(); }});
# CO.observe($("idFilterCT33063382306"), "keydown", {key: Event.KEY_RETURN}, function(event){if($("idFilterCT33063382306Button")){ $("idFilterCT33063382306Button").onclick(); }});
# CO.observe($("idFilterCT33063382309"), "keydown", {key: Event.KEY_RETURN}, function(event){if($("idFilterCT33063382309Button")){ $("idFilterCT33063382309Button").onclick(); }});
# CO.urls["cb186619659"] = function(U){ var vUrl =  new CO.Url("wbstpportfolio.wbStpList?pOrgNr=1&pSort=2%3B28%3B15%3B23%3B10%3B24%3B25%3B19&pLanguageCode=DE&pStpStatus=N&pSjNr=1621") ; return vUrl; }
# CO.urls["cb186621598"] = function(U){ var vUrl =  new CO.Url("WBSTPPORTFOLIO.cbASSkz?pSjNr=1621") ; return vUrl; }
# CO.urls["cb186621599"] = function(U){ var vUrl =  new CO.Url("WBSTPPORTFOLIO.cbASStpName?pSjNr=1621&pLanguageCode=DE&pStpStatus=N") ; return vUrl; }
# //]]>
# </script>
#
# </div>
# </body>
# </html>

# %%
import pandas as pd
from urllib.parse import urljoin

rows = study_programs_content_html.xpath('//tr')
current_degree = None
programs = []

for row in rows:
    tds = row.xpath('./td')
    # Degree header: only one <td> with colspan
    if len(tds) == 1 and tds[0].get('colspan'):
        current_degree = tds[0].text_content().strip()
    # Program row: has class "coRow"
    elif 'coRow' in (row.get('class') or ''):
        program_id = row.get('id')
        if not program_id:
            continue
        if len(tds) < 7:
            continue
        # Field of studies from the 4th <td>
        field_of_studies = tds[3].text_content().strip()
        # Curriculum from the <a> in the 3rd <td>
        curriculum_link = tds[2].xpath('.//span/a[1]')
        curriculum = curriculum_link[0].text_content().strip() if curriculum_link else ""
        # Program link from the <a> in the 3rd <td>
        link = curriculum_link[0].get('href') if curriculum_link else ""
        full_link = urljoin(base_url, link) if link else ""
        # ECTS Credits from the 5th <td>
        ects_credits = tds[4].text_content().strip()
        # Semester from the 6th <td>
        semester = tds[5].text_content().strip()
        programs.append({
            'Degree': current_degree,
            'ID': program_id,
            'Curriculum': curriculum,
            'Field of studies': field_of_studies,
            'ECTS Credits': ects_credits,
            'Semester': semester,
            'Link': full_link,
        })

df = pd.DataFrame(programs)
display(df)
# Out:
#                                                 Degree    ID  \
# 0                                 04 TopMath Promotion  4857
# 1                                     05 Teilpromotion  4094
# 2                                     05 Teilpromotion  2550
# 3                                     05 Teilpromotion  2722
# 4                                     05 Teilpromotion  4127
# ..                                                 ...   ...
# 551  98 Austauschprogramm (nicht studienbeitragspfl...  5315
# 552  98 Austauschprogramm (nicht studienbeitragspfl...  5323
# 553  98 Austauschprogramm (nicht studienbeitragspfl...  5331
# 554  98 Austauschprogramm (nicht studienbeitragspfl...  5310
# 555  99 Zertifikat über die Teilnahme am Integratio...  4574
#
#                                             Curriculum  \
# 0    Mathe. mit zusätzl. Promo.stg. Mathe. - Promot...
# 1                           Agrarwissenschaften (kA/0)
# 2                                   Architektur (kA/0)
# 3                             Bauingenieurwesen (kA/0)
# 4                                     Biochemie (kA/0)
# ..                                                 ...
# 551         Politikwissenschaft - Austausch (kA/20241)
# 552       Research on Teaching and Learning (kA/20241)
# 553          Science and Technology Studies (kA/20241)
# 554                       Sportwissenschaft (kA/20241)
# 555       Gasthörerprogramm für Geflüchtete (kA/20161)
#
#                        Field of studies ECTS Credits Semester  \
# 0                            Mathematik                     8
# 1      Agrarwissenschaft/Landwirtschaft            6        6
# 2                           Architektur                     6
# 3        Bauingenieurwesen/Ingenieurbau                     6
# 4                             Biochemie                     6
# ..                                  ...          ...      ...
# 551                 Politikwissenschaft
# 552  Erziehungswissenschaft (Pädagogik)
# 553               ohne Angabe/ungeklärt
# 554                   Sportwissenschaft
# 555               ohne Angabe/ungeklärt                     1
#
#                                                   Link
# 0    javascript:alert('Details zum Curriculum sind ...
# 1    https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# 2    https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# 3    javascript:alert('Details zum Curriculum sind ...
# 4    https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# ..                                                 ...
# 551  https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# 552  javascript:alert('Details zum Curriculum sind ...
# 553  https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# 554  https://campus.tum.de/wbstpcs.showSpoTree?pStS...
# 555  javascript:alert('Details zum Curriculum sind ...
#
# [556 rows x 7 columns]

# %%
# Iterate over the dataframe and if the Curriculum is "Information Systems (kA/20221)" then store the Link in a variable. 
# We do this to access the website of the study program and scrape the information we need.

curriculum_to_scrape = "Information Systems (kA/20221)"
link_to_scrape = df.loc[df['Curriculum'] == curriculum_to_scrape, 'Link'].values[0]

# Cut the https://campus.tum.de/ from the link and replace it with https://campus.tum.de/tumonline
link_to_scrape = link_to_scrape.replace("https://campus.tum.de/", "https://campus.tum.de/tumonline/")

# Fetch the page for the specific curriculum
curriculum_page = requests.get(link_to_scrape)
# Parse the HTML content of the curriculum page
curriculum_page_content_html = html.fromstring(curriculum_page.content)
# Show the HTML structure of the curriculum page
print(html.tostring(curriculum_page_content_html, pretty_print=True).decode())
# Out:
# <html lang="de" id="id-page-studplan" class="fwk-co app-sts">
# <head>
#
# <meta http-equiv="" name="viewport" content="width=device-width, initial-scale=1">
# <meta http-equiv="pragma" name="" content="no-cache">
# <meta http-equiv="" name="Author" content="Technische Universit&#228;t M&#252;nchen">
#
# <title>Studienplan - TUMonline - Technische Universit&#228;t M&#252;nchen</title>
#
#         <script type="text/javascript">
#         window.caGlobalContext = {};
#         if (window.CA_THEME_CACHE_TOKEN) {
#           window.caGlobalContext.antiCacheToken = window.CA_THEME_CACHE_TOKEN;
#         } else {
#           window.caGlobalContext.antiCacheToken = '1510687599792';
#         }
#
#         var css =
#             "<link rel='stylesheet' href='pages/co-default/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "'>" +
#             "<link id='id-custom-css-vars' rel='stylesheet' href='pages/co-user/css-variables.css?antiCache=" + window.caGlobalContext.antiCacheToken + "'>";
#         console.log('Adding css coplslq: ', css);
#         document.write(css);
#         </script>
#
# <script src="https://campus.tum.de/tumonline/ee/theme/ca2/scripts/conx-custom-scripts.js"></script>
# <link rel="shortcut icon" href="/tumprod/img/co_favicon_tumprod.gif?20101006133616">
# <style type="text/css">
#   A { text-decoration:underline;}
#   BODY { font-size:14px;background-image:url(/tumprod/img/background_production.svg?20210203074442);}
# </style>
# <link rel="stylesheet" type="text/css" href="/tumprod/css/system_standard.css?20241217071038">
# <link rel="stylesheet" type="text/css" href="/tumprod/css/select2.css?20240905073601">
# <style media="screen" type="text/css">
#
# </style> <style media="print, screen" type="text/css">  ul.mktree li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li div.contentDiv { font-size: 1.5em; } ul.mktree li ul li ul li div.contentDiv { font-size: 1.2em; } ul.mktree li ul li ul li ul li div.contentDiv { font-size: 1em; }  </style> <style media="screen, projection" type="text/css">  ul.mktree li.liBullet img { padding-left: 1.3em; } .InactiveNode .kt { background-image: url(/tumprod/img/stp_inactive.png?20180123212315) !important;  background-repeat: no-repeat;  padding-left: 20px !important; } .manChgd, .anerk, .testing { background-position: left top;  background-repeat: no-repeat;  text-indent: 5px; } .manChgd { background-image: url(/tumprod/img/csm_man_ergebnis.gif?20090520163053); } .anerk { background-image: url(/tumprod/img/csm_anerk_ergebnis.gif?20090624161944); } .testing { background-image: url(/tumprod/img/csm_test_ergebnis.gif?20090520163055); } .testing_header { background-image: url(/tumprod/img/csm_test_ergebnis.gif?20090520163055);  background-position: center top;  background-repeat: no-repeat; } .cotable img { vertical-align: middle !important; } .space60 { padding-left: 60px !important; } .space45 { padding-left: 45px !important; } .sms { background-image: url(/tumprod/img/sm-success.gif?20070418170812); } .sme { background-image: url(/tumprod/img/sm-failed.gif?20070418170809); } .smw { background-image: url(/tumprod/img/sm-neutral.gif?20070418170810); } .sme, .sms, .smw { background-repeat: no-repeat;  padding: 5px;  background-position: center center; } .cse { background-image: url(/tumprod/img/form.gif?20190429135426);  background-repeat: no-repeat;  padding-left: 15px; } .rvo { background-image: url(/tumprod/img/red.gif?20031217211315);  background-repeat: no-repeat;  padding-left: 15px;  background-position: center 5px; } .gvo { background-image: url(/tumprod/img/green.gif?20031217211000);  background-repeat: no-repeat;  padding-left: 15px;  background-position: center 5px; } .yvo { background-image: url(/tumprod/img/yellow.gif?20031217211447);  background-repeat: no-repeat;  padding-left: 15px;  background-position: center 5px; } .kt111 { background-image: url(/tumprod/img/stp_2.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt112 { background-image: url(/tumprod/img/stp_2.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt120 { background-image: url(/tumprod/img/stp_4.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt130 { background-image: url(/tumprod/img/stp_4.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt140 { background-image: url(/tumprod/img/stp_4.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt150 { background-image: url(/tumprod/img/stp_4.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt160 { background-image: url(/tumprod/img/stp_4.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt170 { background-image: url(/tumprod/img/stp_2.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt180 { background-image: url(/tumprod/img/stp_3.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt190 { background-image: url(/tumprod/img/stp_5.png?20240130081124);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt202 { background-image: url(/tumprod/img/stp_3.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt203 { background-image: url(/tumprod/img/stp_3.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt204 { background-image: url(/tumprod/img/stp_2.png?20240130081123);  background-repeat: no-repeat;  padding-left: 20px !important; } .kt195 { background-image: url(/tumprod/img/stp_5.png?20240130081124);   ...
# <link rel="stylesheet" type="text/css" href="/tumprod/css/custom_standard.css?20250509185524">
#
# <script type="text/javascript">
#  <!--
#  var GLOBALhomeUrl = "campus.tum.de";
#  var GLOBALhomeIndicator = "<img src='/tumprod/img/co_logo_m_tumprod.gif?20160914063132' BORDER=0 />";
# var GLOBALLOVSucheArr = new Array();
# //-->
# </script>
# </head>
# <body onload="if ( parent &amp;&amp; window &amp;&amp; parent != window ) { var vTitle =' '; if( parent &amp;&amp; parent.detail &amp;&amp; parent.detail.document.title ) { vTitle = vTitle.concat(parent.detail.document.title.replace(/[\n\r\x22\']|^\s*/g, '')); parent.document.title = vTitle; } else { if( parent &amp;&amp; parent.frames[0] &amp;&amp; parent.frames[0].document.title ) {vTitle = vTitle.concat(parent.frames[0].document.title.replace(/[\n\r\x22\']|^\s*/g, '')); parent.document.title = vTitle; } } }">
# <div id="idEePageWrapper">
#
# <div class="pageDisabled" id="idPageDisabled">
# </div>
# <div class="pageLoading" id="idPageLoader">
# Loading
# </div>
# <script charset="WINDOWS-1252" type="text/javascript">
#
#   if(window.addEventListener) window.addEventListener("load", function(){ $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none";}, false);
#   else {  document.attachEvent("onreadystatechange", function(){ if(document.readyState == "complete") { $("idPageDisabled").style.display = "none"; $("idPageLoader").style.display = "none"; }  }, false);  }
#
# </script>
# <link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/styles-integration.css" media="screen">
# <link rel="stylesheet" href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/co-web-cmp.css">
# <div id="id-loader"><span>Loading ...</span></div>
# <co-web-desktop-header></co-web-desktop-header>
# <div id="pageContent">
# <div class="coTooltip" id="GLOBALcoTooltip"></div>
# <table align="center" width="100%" id="idTopPageHeader" class="bodyTable" cellspacing="0" cellpadding="0">
# <tr valign="middle" class="middle coHeaderTopRow">
# <td nowrap class="pageOwner"><span class="s">16 121 Information Systems (20221, Masterstudium, laufend)</span></td>
# <td class="wr100" width="100%">&#160;</td>
# <td>&#160;</td>
# <td></td>
# <td>
# <script src="/tumprod/js/wosinddieframes.jsa?20110330194606" type="text/javascript" charset="WINDOWS-1252"></script>
# </td>
# </tr>
# </table>
# <table align="center" width="100%" id="idPageHeader" class="pageObjectNoTopBorder" cellspacing="0" cellpadding="0">
# <tr align="left" valign="top">
# <td valign="middle" style="padding:10px;width:50%;">
# <table width="100%">
# <tr valign="top">
# <td width="100%"><h1 class="headerHeading noMargin">Studienplan</h1></td>
# </tr>
# <tr valign="top" style="vertical-align:middle">
# <td width="100%"><h2 class="m normalWeight headerObject noMargin" id="idCaSubTitle">Studienjahr 2025/26</h2></td>
# </tr>
# </table>
# </td>
# <td align="right">
# <table id="idPageNavi" class="nav puNav caCoFwk" summary="Men&#252;">
# <tr class="coNavSection ca-key-id ca-id-co-gehe-zu">
# <th nowrap>Gehe zu</th>
# <td>
#
# </td>
# </tr>
# <tr class="coNavGroup ca-key-id ca-id-nav-anzeige">
# <th nowrap>Anzeige</th>
# <td>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4997&amp;pStartSemester=" class="ca-key-id ca-id-nav-link-aktualisieren" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">Aktualisieren</a>
# </td>
# </tr>
# <tr class="coNavGroup ca-key-id ca-id-stpvw-elementart-knoten">
# <th nowrap>Knotenfilter</th>
# <td>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4997&amp;pStartSemester=W&amp;pFilterType=1&amp;pPageNr=&amp;pStpKnotenNr=" class="disabled selected  ca-key-id ca-id-cs-nav-alle" id="Anchor33063395667" onclick="try{ return(false);}catch(e){return($E(e));}">Alle</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4997&amp;pStartSemester=W&amp;pFilterType=20&amp;pPageNr=&amp;pStpKnotenNr=" class="ca-key-id ca-id-cs-nav-alle-expanded" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">Alle (aufgeklappt)</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pSJNr=1621&amp;pStpStpNr=4997&amp;pStartSemester=W&amp;pFilterType=3&amp;pPageNr=&amp;pStpKnotenNr=" class="ca-key-id ca-id-pv-prueftermin">Pr&#252;fungstermin</a>
# </td>
# </tr>
# <tr class="coNavGroup ca-key-id ca-id-nav-studienjahr">
# <th nowrap>Studienjahr</th>
# <td>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pStpStpNr=4997&amp;pStartSemester=&amp;pSjNr=1621" class="disabled selected  ca-dynamic-id ca-id-2025/26" id="Anchor33063395668" onclick="try{ return(false);}catch(e){return($E(e));}">2025/26</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pStpStpNr=4997&amp;pStartSemester=&amp;pSjNr=1619" class="ca-dynamic-id ca-id-2024/25" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2024/25</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pStpStpNr=4997&amp;pStartSemester=&amp;pSjNr=1617" class="ca-dynamic-id ca-id-2023/24" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2023/24</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pStpStpNr=4997&amp;pStartSemester=&amp;pSjNr=1615" class="ca-dynamic-id ca-id-2022/23" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2022/23</a>
# <a href="wbstpcs.showSpoTree?pStStudiumNr=&amp;pStpStpNr=4997&amp;pStartSemester=&amp;pSjNr=1613" class="ca-dynamic-id ca-id-2021/22" onclick="try{CO.Page.disable(); CO.Page.loading();;}catch(e){return($E(e));}">2021/22</a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <div class="invisible" id="idMsgLayerClosed">
# <a href="#" class=" nounderline" id="idToolUnClose" onclick="try{CO.msg.unClose(); return(false);}catch(e){return($E(e));}"><img alt="Meldungen anzeigen" height="24" src="/tumprod/img/msg_maximize.png?20120725215601" width="24"></a><a href="#" class=" nounderline" onclick="try{CO.msg.clear(true); return(false);}catch(e){return($E(e));}"><img alt="Meldungsfenster schlie&#223;en" height="24" src="/tumprod/img/msg_close.png?20120725215554" width="24"></a>
# </div>
# <div id="idMsgLayer">
# <div class="toolbar" id="idToolbar">
# <span class="toolbarSummary invisible" id="idToolbarSummary"><a href="#" class="invisible  nounderline" id="idToolFatalSummary" onclick='try{CO.msg.focus($$(".msgFatal")[0]); return(false);}catch(e){return($E(e));}'><img alt="Fatale Fehler" height="21" src="/tumprod/img/msg_fatal_small.gif?20080430220108" width="21"></a><a href="#" class="invisible  nounderline" id="idToolErrorSummary" onclick='try{CO.msg.focus($$(".msgError")[0]); return(false);}catch(e){return($E(e));}'><img alt="Fehler" height="21" src="/tumprod/img/msg_error_small.gif?20080430220106" width="21"></a><a href="#" class="invisible  nounderline" id="idToolWarningSummary" onclick='try{CO.msg.focus($$(".msgWarning")[0]); return(false);}catch(e){return($E(e));}'><img alt="Warnungen" height="21" src="/tumprod/img/msg_warning_small.gif?20080430220113" width="21"></a><a href="#" class="invisible  nounderline" id="idToolInfoSummary" onclick='try{CO.msg.focus($$(".msgInfo")[0]); return(false);}catch(e){return($E(e));}'><img alt="Informationen" height="21" src="/tumprod/img/msg_info_small.gif?20080430220109" width="23"></a></span><a href="#" class=" nounderline" onclick="try{CO.msg.close(); return(false);}catch(e){return($E(e));}"><img alt="Wichtigste Meldungen anzeigen" height="24" src="/tumprod/img/msg_minimize.png?20120725215605" width="24"></a><a href="#" class="invisible  nounderline" id="idToolMinimize" onclick="try{CO.msg.showMinimized(); return(false);}catch(e){return($E(e));}"><img alt="Wichtigste Meldungen anzeigen" height="24" src="/tumprod/img/msg_diminish.png?20120725215557" width="24"></a><a href="#" class="invisible  nounderline" id="idToolMaximize" onclick="try{CO.msg.showMaximized(); return(false);}catch(e){return($E(e));}"><img alt="Alle Meldungen anzeigen" height="24" src="/tumprod/img/msg_maximize.png?20120725215601" width="24"></a><a href="#" class=" nounderline" onclick="try{CO.msg.clear(true); return(false);}catch(e){return($E(e));}"><img alt="Meldungsfenster schlie&#223;en" height="24" src="/tumprod/img/msg_close.png?20120725215554" width="24"></a>
# </div>
# <div class="msgs">
# <ul class="msgFatal">
# <li>
# </li>
# </ul>
# <ul class="msgError">
# <li>
# </li>
# </ul>
# <ul class="msgWarning">
# <li>
# </li>
# </ul>
# <ul class="msgInfo">
# <li>
# </li>
# </ul>
# </div>
# </div>
# <script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# document.getElementById("idMsgLayer").style.display = "none";
# //]]>
# </script><div id="idErrorBox">
# </div>
# <div class="cotreegrid curriculaSupport ">
# <form action="" enctype="" method="POST" name="Mask33063395670" onsubmit="try{return CO.Mask.submitHandler(this);}catch(e){return($E(e));}" class="coBBNoCSS " id="Mask33063395670">
# <table cellspacing="0" class="cotable" id="tgt">
# <thead>
# <tr>
# <th class=" L">
# Knotenfilter-Bezeichnung</th>
# <th class=" L">
# <span class="TextToolTip " title=" "> </span>
# </th>
# <th class=" C">
# <span class="TextToolTip " title="empf. Sem.">empf. Sem.</span>
# </th>
# <th class=" R">
# <span class="TextToolTip " title="ECTS-Credits">ECTS Cr.</span>
# </th>
# <th class=" R">
# <span class="TextToolTip " title="Gewichtungsfaktor">GF</span>
# </th>
# </tr>
# </thead>
# <tfoot>
# <tr>
# <th colspan="5" class="ftr">
# &#160;
# <span id="idTimer33063395671"></span>
# </th>
# </tr>
# </tfoot>
# <tbody>
# <tr class="coRow z0 hi coTableR  " id="kn2908534">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_1" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_1" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395673 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2908534-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2908534',null,'2908534',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt1 TextToolTip " title="SPO-Version ">[20221] Information Systems</span></a> <a href="#"></a>  </span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>120</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z0 hi coTableSUBR invisible " id="GHK_2908534">
# <td colspan="7">
# <div class="CSS33063395675 " id="GHKC_2908534">
# </div>
# </td>
# </tr>
# <tr class="coRow z1 hi coTableR  kn2908534 " id="kn2933406">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_2" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_2" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2933406-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2933406',null,'2933406',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt6 TextToolTip " title="Pflichtfach [Regelknoten] ">Master's Thesis</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTMzNDA2&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2933406&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2933406&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>30</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z0 hi coTableR  kn2908534 " id="kn2931123">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_3" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_3" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2931123-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2931123',null,'2931123',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt6 TextToolTip " title="Pflichtfach [Regelknoten] ">Pflichtmodule Informatik</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTMxMTIz&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931123&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931123&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>8</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z1 hi coTableR  kn2908534 " id="kn2931138">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_4" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_4" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2931138-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2931138',null,'2931138',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt6 TextToolTip " title="Pflichtfach [Regelknoten] ">Pflichtmodule Wirtschaftsinformatik</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTMxMTM4&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931138&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931138&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=6&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>13</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z0 hi coTableR  kn2908534 " id="kn2936345">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_5" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_5" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2936345-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2936345',null,'2936345',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt8 TextToolTip " title="Wahlfach [Regelknoten] ">Wahlmodule Entwicklungspraktikum</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTM2MzQ1&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2936345&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2936345&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>10</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z1 hi coTableR  kn2908534 " id="kn2933410">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_6" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_6" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2933410-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2933410',null,'2933410',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt8 TextToolTip " title="Wahlfach [Regelknoten] ">&#220;bergreifende Wahlmodule</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTMzNDEw&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2933410&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2933410&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>53</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# <tr class="coRow z0 hi coTableR  kn2908534 " id="kn2931176">
# <td class=" L">
# <a href="#" name="coTblIdx_tgt_7" onblur="try{CO.Table.blurRow(this);}catch(e){return($E(e));}" onfocus='try{CO.Table._focusRow($("tgt"), this);}catch(e){return($E(e));}' class="coTabRA" id="coTblIdx_tgt_7" onclick="try{ return(false);}catch(e){return($E(e));}"></a><div class="CSS33063395676 ">
# <span><a href="#" class="KnotenLink noTextDecoration  " id="kn2931176-toggle" onclick="try{var cs_vIsReloaded = cs_loadSubElems.call(this,'kn2931176',null,'2931176',null,null);;return false;}catch(e){return($E(e));}"><span class="KnotenText noBorder kt kt8 TextToolTip " title="Wahlfach [Regelknoten] ">Wahlmodule &#220;berfachliche Grundlagen</span> </a><a href="https://campus.tum.de/tumonline/ee/ui/ca2/app/desktop/#/slc.tm.cp/student/courses?curriculumVersionId=4997&amp;$filter=courseFilterResourceId-eq=RUxFTUVOVDtWRVJTSU9OX0lEOjQ5OTc7Tk9ERV9JRDoyOTMxMTc2&amp;$ctx=lang=" class="CSS33063395678 " title="Alle Lehrveranstaltungen anzeigen"><img alt="" height="16" src="/tumprod/img/action_export.png?20150126160713" width="16" class="CSS33063395677 "></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931176&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=&amp;pIsLeaf=&amp;pAnsicht=&amp;pAllItemsSelected=N&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="14" src="/tumprod/img/uhr3.gif?20031217211418" width="14"></a> <a href="cbstpcs.cbCalendarPlan?pStpKnNr=2931176&amp;pSjNr=1621&amp;pStpStpNr=4997&amp;pStpSTypNr=10000&amp;pStpKnTypNr=8&amp;pOrgNr=1&amp;pTarget=P&amp;pIsLeaf=&amp;pAnsicht=&amp;pStartSemester=W" class=" nounderline" onclick="try{return(CO.WIN(this));}catch(e){return($E(e));}" title="Ort/Zeit"><img alt="" height="19" src="/tumprod/img/weeklys.gif?20031217211434" width="20"></a></span>
# </div>
# </td>
# <td class=" L">
# <div class="L CSS33063395674 ">
# <span><a href="#"></a></span>
# </div>
# </td>
# <td class=" C">
# <div class="C ">
# <span></span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>6</span>
# </div>
# </td>
# <td class=" R">
# <div class="R ">
# <span>1</span>
# </div>
# </td>
# </tr>
# </tbody>
# </table>
# </form>
# </div>
# <br><br>
# <table id="idPageFooter" class="nomargins pageFooter" width="100%" cellpadding="0" cellspacing="0">
# <script src="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/co-web-cmp.js"></script>
#
#         <co-web-desktop-controller desktop-api-base-href="https://campus.tum.de/tumonline/co/co-desktop" public-api-base-href="https://campus.tum.de/tumonline/co/public" web-cmp-base-href="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp">
#         </co-web-desktop-controller>
#
# <co-web-desktop-footer></co-web-desktop-footer>
# <script src="https://campus.tum.de/tumonline/co/co-desktop/co-web-cmp/assets/co-web-event-handler.js"></script>
# </table>
# </div>
# <div id="idFirebug">
# </div>
# <div class="invisible" id="idWindowTemplate">
# <div class="overlayWindowContent" id="idOverlayWindowContent">
# </div>
# <div class="overlayWindowHeader">
# <div>
# <span class="overlayWindowTools"><a href="#" class=" nounderline" id="idOverlayClose" onclick="try{CO.Window.close(this);return(false);}catch(e){return($E(e));}"><img alt="" height="24" src="/tumprod/img/msg_close.png?20120725215554" width="24"></a></span><h1 class="overlayWindowTitle" id="idOverlayWindowTitle">
# Loading ...
# </h1>
# </div>
# </div>
# </div>
# <div class="invisible" id="idDialog">
# <p id="idDialogTitle">
# </p>
# <p id="idDialogMsg">
# </p>
# <p id="idChoice">
# </p>
# <div id="idDialogButtonBar">
# </div>
# </div>
# <!--
#  ToolTip Overlays begin-->
# <!--
#  ToolTip Overlays end-->
# <div class="invisible" id="ToolTipOverlayCBCT">
# </div>
# <script charset="WINDOWS-1252" src="/tumprod/js/prototype.js?20230718075524" type="text/javascript"></script><script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# if(typeof(CO) === "undefined")
#   var CO = Class.create();
# CO.IMGPATH = "https://campus.tum.de/tumprod/img/";
# //]]>
# </script><script charset="WINDOWS-1252" src="/tumprod/js/scriptaculous.jsa?20080730194911" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/effects.jsa?20080730194907" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/dragdrop.jsa?20090318173923" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cojs.jsa?20250513075455" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cotable.jsa?20170405175145" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/coeffect.jsa?20150126164151" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/comsg.jsa?20150506180429" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/utf8count.jsa?20250324091721" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/system_standard_js.js?20110525190919" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/co_loc_custom_standard_js.js?20250314181441" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cocallback.jsa?20231010073535" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cotabjs.jsa?20150506183132" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/comaskjs.jsa?20250218080956" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/calendar.jsa?20151211212952" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/calendar-setup.jsa?20151211212953" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/calendar-en.jsa?20100421164239" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/calendar-de.jsa?20150126172500" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/codialogjs.jsa?20150617210628" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/jquery.jsa?20131216165544" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/select2-js.js?20151211220255" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/select2_locale_de.js?20150506180435" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/cocombobox.js?20150506180430" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/prototip.jsa?20100210160927" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/coautosuggestion.js?20131216170447" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/fileuploader.jsa?20180508173003" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/comaskjs.jsa?20250218080956" type="text/javascript"></script><script charset="WINDOWS-1252" src="/tumprod/js/wbjsincludes_de.js" type="text/javascript"></script>
#
# <script charset="WINDOWS-1252" type="text/javascript">//<![CDATA[
# $NS("js_icons");
# self.js_icons.idNav33063395666_minus_img = new CO.Image("/tumprod/img/menu_tee_minus_m_tumprod.png?20160914063609", "", {"class" : ""});
# self.js_icons.idNav33063395666_plus_img = new CO.Image("/tumprod/img/menu_tee_plus_m_tumprod.png?20160914063623", "", {"class" : ""});
# self.js_icons.idNav33063395666_chkbox_unselected = new CO.Image("/tumprod/img/checkbox_unchecked.png?20080825172356", "", {"class" : ""});
# self.js_icons.idNav33063395666_chkbox_selected = new CO.Image("/tumprod/img/checkbox_checked.png?20080825172351", "", {"class" : ""});
# self.js_icons.idNav33063395666_chkbox_halfselected = new CO.Image("/tumprod/img/checkbox_grey.png?20080825172353", "", {"class" : ""});
#  if ( window.jsTree == undefined ) { window.jsTree = new Object(); };
# self.sms = "Meldungen zur SPO Berechnung anzeigen";
# self.sme = "es sind Fehler bei der Berechnung aufgetreten";
# self.smw = "es sind Warnungen bei der Berechnung aufgetreten";
# self.toggleGrp = function(pRow)
# {
#
#           var vRow = $(pRow);
#           if(vRow.nodeName != "TR") vRow = CO.Table.getRowOf(vRow);
#
#           var vRowType = CO.Table.getRowType(vRow);
#
#           if(vRowType == "coTableGR1")
#           {
#             while(true)
#             {
#               vRow = vRow.next();
#
#               if(!vRow) return;
#
#               vRowType = CO.Table.getRowType(vRow);
#               if(vRowType == "coTableGR1") return;
#
#               if(vRowType == "coTableR" || vRowType == "coTableGR2") {
#                   if ( vRow.hasClassName("invisible") )
#                      vRow.coShow();
#                   else
#                      vRow.coHide();
#               }
#             }
#           }
#
# };
# self.resetWahl_url = new CO.Url("cbstpcs.cbResetWahl?pStStudiumNr=&pIsStudSicht=FALSE");
# function cs_askServerResetWahl(pStpKnotenNr)
#                {
#                  resetWahl_url.setParam("pStpKnotenNr", pStpKnotenNr);
#                  resetWahl_url.setOptions({"asynchronous" : false});
#                  resetWahl_url.callback(document.body);
#
#                  if (vIsReallyToBeReset)
#                  {
#                   //alert("debug CO: resetting done");
#                   return true;
#                  }
#                  else
#                  {
#                   //alert("debug CO: resetting not done");
#                   return false;
#                  }
#                }
#
# self.setWahl_url = new CO.Url("cbstpcs.cbSetWahl?pStStudiumNr=&pIsStudSicht=FALSE");
# function cs_askServerSetWahl(pStpKnotenNr)
#                {
#                  setWahl_url.setParam("pStpKnotenNr", pStpKnotenNr);
#                  setWahl_url.setOptions({"asynchronous" : false});
#                  setWahl_url.callback(document.body);
#
#                  if (vIsReallyToBeSet)
#                  {
#                   //alert("debug CO: setting done");
#                   return true;
#                  }
#                  else
#                  {
#                   //alert("debug CO: setting not done");
#                   return false;
#                  }
#                }
#
# self.cbToggleGewaehlt = function(vStpKnotenNr,vStpkStpkNr, vGewaehlt,vId,vLeistung)
# {
# // jka, 14.08.2013, immediately deactivate the onclick-event
#                   // of the selected node and its siblings
#                   // in order to prevent display problems of the spo-tree
#                   // when selecting/deselecting too fast the WAHL-checkbox
#                   // @see SR-25172
#                   $$(".kn"+vStpkStpkNr).each(
#                         function(e) {
#                           if (e)
#                           {
#                             var checkbox = e.select("input")[2];
#                             if (checkbox)
#                             {
#                               checkbox.setAttribute("onclick", "return false;");
#                               checkbox.disabled=true;
#                             }
#                           }
#                         }
#                       );
#
#                   var vAction = (vGewaehlt == "undefined" || vGewaehlt == "" || vGewaehlt == null ) ? "GWR" : "DELGWR";
#                   var vHasLeistung = (vLeistung == "undefined" || vLeistung == "" || vLeistung == null ) ? false : true;
#                   var vTarget = eval(vId);
#                   var vAllowed = true;
#                   var vIsOk = false;
#
#                  // l&#246;schen eines Gew&#228;hlt-Records mit Leistung muss best&#228;tigt werden
#                  if ( vAction == "DELGWR" && vHasLeistung )
#                  {new CO.ConfirmDialog( function( pAction ) {
#            if ( pAction == "YES" ) {vIsOk = cs_askServerResetWahl(vStpKnotenNr);
#            } else { return false;
#            }
#          }
#          ).open( "Leistungszuordnungen werden gel&#246;scht! Fortfahren?", this );
#
#                  }
#                  else
#                  {
#                      if (vAction == "GWR")
#                      {
#                        vIsOk = cs_askServerSetWahl(vStpKnotenNr);
#                      }
#                      else
#                      {
#                        vIsOk = cs_askServerResetWahl(vStpKnotenNr);
#                      }
#                  }
#
#                  // jka, 14.08.2013, if setting/resetting-action has not been
#                  // successfully done, we need to reactivate the onclick-event
#                  // of the selected node and its siblings
#                  // @see SR-25172
#                  if (!vIsOk)
#                  {
#                    // resetting and setting is NOT ok => there's a  need to reactivate the checkbox and the corersponding onclick-event
#                     $$(".kn"+vStpkStpkNr).each(
#                           function(e) {
#                             if (e)
#                             {
#                               var checkbox = e.select("input")[2];
#                               if (checkbox)
#                               {
#                                 var orig_checkbox_value = e.select("input")[1].value;
#                                 var orig_checkbox_onclickevent_value = e.select("input")[0].value;
#                                 if (orig_checkbox_value == 'FALSE')
#                                 {
#                                   checkbox.checked = false;
#                                 }
#                                 else
#                                 {
#                                   checkbox.checked = true;
#                                 }
#                                 checkbox.setAttribute("onclick", orig_checkbox_onclickevent_value);
#                                 checkbox.disabled=false;
#                               }
#                             }
#                           }
#                         );
#                  }
#
# };
# self.wwol = function(pElem)
# {
# try{CO.Window.open.apply($(pElem), [pElem.href, CO.Window.typeNormal, {"overlay" : "true","name" : "wdCsWideOverlay"}]); return(false);}catch(e){return($E(e));}
# };
# self.checkFinish = function(pStStudiumNr, pJob, pStpStpNr, pStPersonNr, pIsStudSicht)
# {
# var url = "wbstpcs.cbcheckfinish?pststudiumnr="+pStStudiumNr+"&pJobNr="+pJob+"&pStpStpNr="+pStpStpNr+"&pStPersonNr="+pStPersonNr+"&pIsStudSicht="+pIsStudSicht;
#                $('tgt').callback( url );
# };
# self.cs_rowJal = function(pNoImgToggle)
# {
# $$("#tgt > tbody > tr.coTableR").each(
#                   function(e,i) {
#                     if (i%2==0) {
#                       e.removeClassName("z1");
#                       e.addClassName("z0");
#                     } else {
#                       e.removeClassName("z0");
#                       e.addClassName("z1");
#                     }
#                     var noToggle = ( typeof(pNoImgToggle) == "undefined" ) ? false : true;
#                     // diese ID ist nicht immer verf&#252;gbar (fehlendes (+)-Icon) -- if erg&#228;nzt lr86 2013-06-19
#                     if (e.id !== "") {
#                       if ( $$("#tgt > tbody > tr." +e.id ).length > 0 && noToggle == false ) {
#                         e.down(".KnotenLink").style.backgroundImage = "url(/tumprod/img/menu_tee_minus_m_tumprod.png?20160914063609)";
#                       }
#                     }
#                   });
#
# };
# self.cs_cbRefreshSubtree = function(pKnotenNr)
# {
# e = $("kn"+pKnotenNr+"-toggle")
#                       $$(".kn"+pKnotenNr).each(
#                         function(e) {
#                           e.removeClassName("kn"+pKnotenNr);
#                           e.addClassName("del"+pKnotenNr);
#                         }
#                       );
#                       if (e != null)
#                       {
#                         var cs_vIsSpoTreeReloaded = cs_loadSubElems.call(e,"kn"+pKnotenNr,null,pKnotenNr,null,"TR.del"+pKnotenNr);
#                         if (cs_vIsSpoTreeReloaded)
#                         {
#                           return true;
#                         }
#                         else
#                         {
#                           return false;
#                         }
#                       }
#                       else
#                       {
#                         return false;
#                       }
#
# };
# self.cs_reloadSPOTree_url = new CO.Url("wbStpCs.cbSpoTree?pStStudiumNr=&pStpStpNr=4997&pStPersonNr=&pSJNr=1621&pIsStudSicht=FALSE&pShowErg=J&pHideInactive=TRUE&pCaller=");
# function cs_askServerReloadSpoTree(pStpKnotenNr, pId, pAction, pStpSTypNr, pStartSemester, pImgUrlCol, pDelClass, pThis)
#                    {
#                      cs_reloadSPOTree_url.setParam("pStpKnotenNr", pStpKnotenNr);
#                      cs_reloadSPOTree_url.setParam("pId", pId);
#                      cs_reloadSPOTree_url.setParam("pAction", pAction);
#                      cs_reloadSPOTree_url.setParam("pStpSTypNr", pStpSTypNr);
#                      cs_reloadSPOTree_url.setParam("pStartSemester", pStartSemester);
#                      cs_reloadSPOTree_url.setOptions({
#                          "onCustomSuccess" : function(test)
#                          {
#                            $$(pDelClass).each(function(e){e.remove();});
#                            cs_rowJal("noImgToggle");
#                            pThis.style.backgroundImage = "url("+pImgUrlCol+")";
#                          }
#                        , "asynchronous" : false
#                      });
#                      cs_reloadSPOTree_url.callback(document.body);
#
#                      if (cs_vIsSPOTreeReloaded)
#                      {
#                       //alert("debug CO: reloading done");
#                       return true;
#                      }
#                      else
#                      {
#                       //alert("debug CO: reloading not done");
#                       return false;
#                      }
#                    }
#
# self.cs_loadSubElems = function(pSubClass, pKey, pKnoten, pStartSemester, pDelClass)
# {
#  var k   = ( typeof(pKnoten) == "undefined" ) ? null : pKnoten;
#                     var key = ( typeof(pKey) == "undefined" ) ? null : pKey;
#                     var startSem = ( typeof(pStartSemester) == "undefined" ) ? null : pStartSemester;;
#                     var childcount = $$("."+pSubClass).length;
#                     var vImgUrlExp = (k) ? "/tumprod/img/menu_tee_plus_m_tumprod.png?20160914063623" : "/tumprod/img/expand.gif?20190429135420";
#                     var vImgUrlCol = (k) ? "/tumprod/img/menu_tee_minus_m_tumprod.png?20160914063609" : "/tumprod/img/collaps.gif?20190429135418";
#
#                     if ( childcount == 0 ) {
#                         $(this).style.backgroundImage = "url(/tumprod/img/spinner.gif?20080326142525)";
#                         cs_vIsReloaded = cs_askServerReloadSpoTree(k, pSubClass, childcount, key, startSem, vImgUrlCol, pDelClass, this);
#                         return cs_vIsReloaded;
#                     } else {
#                           $(this).style.backgroundImage = "url("+vImgUrlExp+")";
#                           $$("."+pSubClass).each( function(e) { e.remove(); });
#                           $$('tr[id^="PATH_'+pSubClass+'"]').each( function(e) {
#                             e.remove();
#                           });
#                           cs_rowJal("noImgToggle");
#                           return false;
#                      }
#                      return false;
# };
# self.loadGHKTable = function(pParamID, pParamKnoten, pParamRootKnoten)
# {
# $(this).callback("wbstpcs.cbshowghks_new?psjnr=1621&pStStudiumNr=&pIsStudSicht=FALSE", {dummy:true, parameters: {pid:pParamID,pStpKnotenNr:pParamKnoten,pRootKnotenNr:pParamRootKnoten} }); return false;
# };
# self.showAllPaths = function(pTableId, pRowId, pStpStpNr, pStStudiumNr, pColspan, pStPersonNr)
# {
#  var ar = $(pTableId).getElementsByClassName('coTableR');
#                   var allesAusgeklappt = $(pTableId).hasClassName('out');
#                   window.vStpStpNr = pStpStpNr;
#
#                   if (allesAusgeklappt) {
#                     $(pTableId).removeClassName('out');
#                     $(pTableId).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_rechts.gif?20100616174305">');
#                   } else {
#                     $(pTableId).addClassName('out');
#                     $(pTableId).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_unten.gif?20100616174307">');
#                   };
#
#                   for (var index = 0; index < ar.length; index++) {
#                     if ( ar[index].identify().startsWith(pRowId) ) {
#                       var item = ar[index].identify().sub(pRowId,'');
#
#                       if ($('PATH_'+pRowId+item)) {
#                          if ( (!allesAusgeklappt && $('PATH_'+pRowId+item).hasClassName('invisible'))
#                            || (allesAusgeklappt && !$('PATH_'+pRowId+item).hasClassName('invisible'))
#                             )
#                          {
#                            $('PATH_'+pRowId+item).coToggle();
#                            if ($('PATH_'+pRowId+item).hasClassName('invisible')) {
#                              $(pRowId+item).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_rechts.gif?20100616174305">');
#                            } else {
#                              $(pRowId+item).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_oben.gif?20100621101857">');
#                            };
#                          };
#                       } else {
#                         CO.Callback.request("wbstpcs.cbshowPath", { parameters: {pStpStpNr:pStpStpNr,pStStudiumNr:pStStudiumNr,pColspan:pColspan,pStPersonNr:pStPersonNr,pid:pRowId+item,pTo:item} });
#                         $(pRowId+item).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_oben.gif?20100621101857">');
#                       };
#                     }
#                   };
# };
# self.togglePath = function(pRowId, pStpStpNr, pStStudiumNr, pColspan, pStPersonNr, pStpKnotenNr)
# {
# if (pStStudiumNr == 0) { pStStudiumNr = null; };
#                  if (pStPersonNr == 0) { pStPersonNr = null; };
#                  if ($('PATH_'+pRowId)) {
#                        $('PATH_'+pRowId).coToggle();
#                        if ($('PATH_'+pRowId).hasClassName('invisible')) {
#                          $(pRowId).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_rechts.gif?20100616174305">')
#                        } else {
#                          $(pRowId).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_oben.gif?20100621101857">')
#                        };
#                     } else {
#                       CO.Callback.request("wbstpcs.cbshowPath", { parameters: {pStpStpNr:pStpStpNr,pStStudiumNr:pStStudiumNr,pColspan:pColspan,pStPersonNr:pStPersonNr,pid:pRowId,pTo:pStpKnotenNr} });
#                       $(pRowId).getElementsByClassName('cs-path')[0].update('... <IMG SRC="/tumprod/img/pfeil_oben.gif?20100621101857">');
#                     } return false;
# };
#
#       var delTabUnselectableClass = function(element, index, array) {
#         try {
#           element.coTab.setSelectable(element.id,true);
#         } catch(e) {
#         };
#       };
#
#
#       var getHauptverantwortlicherNr = function() {
#         var vHauptverantwortlicher;
#         CO.Table.getRowInputS(CO.Table.getRowS($("id_spo_knv_show_table"), "coTableR", {}), "pHauptverantwortlichNr").each(function(pInput){
#           if(pInput.checked) { vHauptverantwortlicher = $F(pInput); }
#         });
#         return vHauptverantwortlicher;
#       }
#
# Event.observe(window, "load", function(){cs_rowJal();});
# if($("tgt")) $CO("tgt").co.multiple = true;
# CO.Table.init("tgt");
# CO.observe($("Anchor33063395667"), "click", {}, function(event){CO.Page.loadUrl("wbstpcs.showSpoTree?pStStudiumNr=&pSJNr=1621&pStpStpNr=4997&pStartSemester=W&pFilterType=1&pPageNr=&pStpKnotenNr=")});
# CO.observe($("Anchor33063395668"), "click", {}, function(event){CO.Page.disable(); CO.Page.loading();;});
# //]]>
# </script>
#
# </div>
# </body>
# </html>

# %%
import pandas as pd

# Find all rows in the table body
rows = curriculum_page_content_html.xpath('//table[@id="tgt"]/tbody/tr')
data = []

for row in rows:
    tds = row.xpath('./td')
    # Only process rows with at least 5 columns (the relevant data rows)
    if len(tds) >= 5:
        # Knotenfilter-Bezeichnung (first <td>)
        knotenfilter = tds[0].xpath('.//span/span[@class="KnotenText noBorder kt kt1 TextToolTip " or contains(@class, "KnotenText")]/text()')
        knotenfilter = knotenfilter[0].strip() if knotenfilter else tds[0].text_content().strip()
        # empf. Sem. (third <td>)
        empf_sem = tds[2].text_content().strip()
        # ECTS Cr. (fourth <td>)
        ects_cr = tds[3].text_content().strip()
        # GF (fifth <td>)
        gf = tds[4].text_content().strip()
        data.append({
            "Knotenfilter-Bezeichnung": knotenfilter,
            "empf. Sem.": empf_sem,
            "ECTS Cr.": ects_cr,
            "GF": gf
        })

df_knoten = pd.DataFrame(data)
display(df_knoten)
# Out:
#               Knotenfilter-Bezeichnung empf. Sem. ECTS Cr. GF
# 0          [20221] Information Systems                 120  1
# 1                      Master's Thesis                  30  1
# 2             Pflichtmodule Informatik                   8  1
# 3  Pflichtmodule Wirtschaftsinformatik                  13  1
# 4     Wahlmodule Entwicklungspraktikum                  10  1
# 5             Übergreifende Wahlmodule                  53  1
# 6  Wahlmodule Überfachliche Grundlagen                   6  1

# %%
import pandas as pd

rows = curriculum_page_content_html.xpath('//table[@id="tgt"]/tbody/tr')
data = []

i = 0
while i < len(rows):
    row = rows[i]
    tds = row.xpath('./td')
    if len(tds) >= 5:
        # Outer row values
        knotenfilter = tds[0].xpath('.//span/span[@class="KnotenText noBorder kt kt1 TextToolTip " or contains(@class, "KnotenText")]/text()')
        knotenfilter = knotenfilter[0].strip() if knotenfilter else tds[0].text_content().strip()
        empf_sem = tds[2].text_content().strip()
        ects_cr = tds[3].text_content().strip()
        gf = tds[4].text_content().strip()
        # Check for sub-rows (Level 2)
        next_row = row.getnext()
        has_subrow = False
        if next_row is not None:
            sub_tds = next_row.xpath('./td')
            if len(sub_tds) == 1:
                # There may be multiple Level 2 entries in the subrow
                level2_spans = sub_tds[0].xpath('./div/span/a/span') # TODO: Something is wrong here
                level2_links = sub_tds[0].xpath('./div/span/a/img') # TODO: Something is wrong here
                for idx, level2_elem in enumerate(level2_spans):
                    level2 = level2_elem.text_content().strip()
                    link = level2_links[idx].get('src') if idx < len(level2_links) else ""
                    data.append({
                        "Knotenfilter-Bezeichnung": knotenfilter,
                        "Knotenfilter-Bezeichnung Level 2": "",
                        "empf. Sem.": empf_sem,
                        "ECTS Cr.": ects_cr,
                        "GF": gf,
                        "Link": ""
                    })
                has_subrow = True
        if not has_subrow:
            data.append({
                "Knotenfilter-Bezeichnung": knotenfilter,
                "Knotenfilter-Bezeichnung Level 2": "",
                "empf. Sem.": empf_sem,
                "ECTS Cr.": ects_cr,
                "GF": gf,
                "Link": ""
            })
        i += 2 if has_subrow else 1
    else:
        i += 1

df_knoten = pd.DataFrame(data)
display(df_knoten)
# Out:
#               Knotenfilter-Bezeichnung Knotenfilter-Bezeichnung Level 2  \
# 0                      Master's Thesis
# 1             Pflichtmodule Informatik
# 2  Pflichtmodule Wirtschaftsinformatik
# 3     Wahlmodule Entwicklungspraktikum
# 4             Übergreifende Wahlmodule
# 5  Wahlmodule Überfachliche Grundlagen
#
#   empf. Sem. ECTS Cr. GF Link
# 0                  30  1
# 1                   8  1
# 2                  13  1
# 3                  10  1
# 4                  53  1
# 5                   6  1
